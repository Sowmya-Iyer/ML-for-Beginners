# %% [markdown]
# Dataset is downloaded from Kaggle. Link: https://www.kaggle.com/giripujar/hr-analytics

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("HR_comma_sep.csv")
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# 0                   3              0     1                      0      sales
# 1                   6              0     1                      0      sales
# 2                   4              0     1                      0      sales
# 3                   5              0     1                      0      sales
# 4                   3              0     1                      0      sales
#
#    salary
# 0     low
# 1  medium
# ...

# %% [markdown]
# <h2>Exploratory Data Analysis and visualization</h2>

# %%
left = df[df.left==1]
left.shape
# Out:
# (3571, 10)

# %%
retained = df[df.left==0]
retained.shape
# Out:
# (11428, 10)

# %%
df.groupby('left').mean()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# left
# 0               0.666810         0.715473        3.786664
# 1               0.440098         0.718113        3.855503
#
#       average_montly_hours  time_spend_company  Work_accident  \
# left
# 0               199.060203            3.380032       0.175009
# 1               207.419210            3.876505       0.047326
#
#       promotion_last_5years
# left
# 0                  0.026251
# 1                  0.005321

# %% [markdown]
# From above table we can draw following conclusions,
# <ol>
#     <li>**Satisfaction Level**: Satisfaction level seems to be relatively low (0.44) in employees leaving the firm vs the retained ones (0.66)</li>
#     <li>**Average Monthly Hours**: Average monthly hours are higher in employees leaving the firm (199 vs 207)</li>
#     <li>**Promotion Last 5 Years**: Employees who are given promotion are likely to be retained at firm </li>
# </ol>

# %% [markdown]
# **Salary on employee's retention**

# %%
pd.crosstab(df.salary,df.left).plot(kind='bar')

# %% [markdown]
# Above bar chart shows employees with high salaries are likely to not leave the company

# %% [markdown]
# **Department on employee retention rate**

# %%
pd.crosstab(df.Department,df.left).plot(kind='bar')

# %% [markdown]
# From above chart there seem to be some impact of department on employee retention but it is not major hence we will ignore department in our analysis

# %% [markdown]
# <h3>From the above we can infer that the following variables can be taken as independant variables in our model</h3>
# <ol>
#     <li>Salary</li>
#     <li>Satisfaction Level</li>
#     <li>Average Monthly Hours</li>
#     <li>Promotion Last 5 Years</li>
# </ol>

# %%
subdf = df[['satisfaction_level','average_montly_hours','promotion_last_5years','salary']]
subdf.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low

# %% [markdown]
# **dummy variable in salary**

# %% [markdown]
# Salary has all text data. It needs to be converted to numbers and here using dummy variables.

# %%
salary_dummies = pd.get_dummies(subdf.salary, prefix="salary")
df_with_dummies = pd.concat([subdf,salary_dummies],axis='columns')

# %%
df_with_dummies.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  salary  \
# 0                0.38                   157                      0     low
# 1                0.80                   262                      0  medium
# 2                0.11                   272                      0  medium
# 3                0.72                   223                      0     low
# 4                0.37                   159                      0     low
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
df_with_dummies.drop('salary',axis='columns',inplace=True)
df_with_dummies.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                0.38                   157                      0
# 1                0.80                   262                      0
# 2                0.11                   272                      0
# 3                0.72                   223                      0
# 4                0.37                   159                      0
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
X = df_with_dummies
X.head()
# Out:
#    satisfaction_level  average_montly_hours  promotion_last_5years  \
# 0                0.38                   157                      0
# 1                0.80                   262                      0
# 2                0.11                   272                      0
# 3                0.72                   223                      0
# 4                0.37                   159                      0
#
#    salary_high  salary_low  salary_medium
# 0            0           1              0
# 1            0           0              1
# 2            0           0              1
# 3            0           1              0
# 4            0           1              0

# %%
y = df.left

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_test
# Out:
# 7269     0
# 8160     0
# 6100     0
# 2303     0
# 10545    0
#         ..
# 8327     0
# 1072     1
# 13937    0
# 9426     0
# 11412    0
# Name: left, Length: 10500, dtype: int64

# %%
print(model.predict(X_test))
# Out:
# [0 0 0 ... 0 0 0]

# %%
print ("Model Accuracy : {}".format(model.score(X_test,y_test)))
# Out:
# Model Accuracy : 0.7702857142857142
